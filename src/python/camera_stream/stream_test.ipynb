# %%
import cv2
from matplotlib import pyplot as plt

# %%
capture = cv2.VideoCapture(0)
_, frame = capture.read()
cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()
print(frame.shape)
capture.release()
# Out:
# (480, 640, 3)

# %%
def returnCameraIndexes():
    # checks the first 20 indexes.
    index = 0
    arr = []
    i = 20
    while i > 0:
        cap = cv2.VideoCapture(index)
        if cap.read()[0]:
            arr.append(index)
            cap.release()
        index += 1
        i -= 1
    return arr

returnCameraIndexes()
# Out:
# [ WARN:0@39.319] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video1): can't open camera by index
# [ERROR:0@39.323] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@40.265] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video3): can't open camera by index
# [ERROR:0@40.269] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@41.476] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video5): can't open camera by index
# [ERROR:0@41.482] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@42.059] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video7): can't open camera by index
# [ERROR:0@42.061] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@43.269] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video9): can't open camera by index
# [ERROR:0@43.274] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@43.852] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video11): can't open camera by index
# [ERROR:0@43.857] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@43.857] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video12): can't open camera by index
# [ERROR:0@43.860] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@43.860] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video13): can't open camera by index
# [ERROR:0@43.862] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@43.862] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video14): can't open camera by index
# [ERROR:0@43.864] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@43.864] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video15): can't open camera by index
# [ERROR:0@43.865] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@43.865] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video16): can't open camera by index
# [ERROR:0@43.866] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@43.866] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video17): can't open camera by index
# [ERROR:0@43.868] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@43.868] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video18): can't open camera by index
# [ERROR:0@43.869] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [ WARN:0@43.870] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video19): can't open camera by index
# [ERROR:0@43.871] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# [0, 2, 4, 6, 8, 10]
